# %% [markdown]
# <a href="https://colab.research.google.com/github/madhants/Madhan/blob/main/Pandas%20data%20frame%20%20dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("/fever_hospital_data.csv")  # Replace with actual file name
print(df.head())
# Out:
#    PatientID   Name  Age Gender Disease         Treatment  Duration Alive  \
# 0       1001    Eva   68      M   Fever         Ibuprofen         5   Yes
# 1       1002  David    0      F   Fever  Rest & Hydration         8   Yes
# 2       1003    Ian   82      M   Fever       Antibiotics        10   Yes
# 3       1004  David   33      M   Fever  Rest & Hydration         2   Yes
# 4       1005   Jane   68      F   Fever         IV Fluids         6   Yes
#
#     HospitalName AdmissionDate
# 0  Global Health    2025-06-15
# 1      GreenLife    2025-06-30
# 2       MetroMed    2025-06-07
# 3       CityCare    2025-06-30
# 4       MetroMed    2025-06-16

# %%
print(df.tail())
# Out:
#     PatientID   Name  Age Gender Disease         Treatment  Duration Alive  \
# 45       1046  David   90      M   Fever         IV Fluids         6   Yes
# 46       1047    Ian   29      F   Fever         Ibuprofen         8   Yes
# 47       1048    Eva   41      M   Fever  Rest & Hydration         4   Yes
# 48       1049  Grace   84      M   Fever         Ibuprofen         8   Yes
# 49       1050    Ian   59      F   Fever         Ibuprofen        10   Yes
#
#      HospitalName AdmissionDate
# 45       MetroMed    2025-06-22
# 46       MetroMed    2025-06-20
# 47       MetroMed    2025-06-11
# 48       CityCare    2025-06-15
# 49  Apollo Clinic    2025-06-18

# %%
df.columns
# Out:
# Index(['PatientID', 'Name', 'Age', 'Gender', 'Disease', 'Treatment',
#        'Duration', 'Alive', 'HospitalName', 'AdmissionDate'],
#       dtype='object')

# %%
df. describe()
# Out:
#         PatientID        Age   Duration
# count    50.00000  50.000000  50.000000
# mean   1025.50000  51.440000   5.520000
# std      14.57738  27.612597   2.742262
# min    1001.00000   0.000000   2.000000
# 25%    1013.25000  26.500000   3.000000
# 50%    1025.50000  59.000000   5.500000
# 75%    1037.75000  75.000000   8.000000
# max    1050.00000  90.000000  10.000000
